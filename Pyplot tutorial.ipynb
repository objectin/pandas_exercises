# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('dracula')

# %% [markdown]
# ### 1. 기본 개념

# %% [markdown]
# ![Plots](https://laboputer.github.io/assets/img/ml/python/matplotlib/2.JPG)

# %% [markdown]
# ### 2. Line plot, Figure

# %%
plt.plot([3, 1, 5, 2])
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ![Figure](https://laboputer.github.io/assets/img/ml/python/matplotlib/1.JPG)

# %%
x = np.linspace(0, 2*np.pi, 50)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 50)

plt.plot(x, np.sin(x))
plt.plot(x, 10*np.cos(2*x))
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 50)
ax1 = plt.gca()
ax2 = plt.gca().twinx()

ax1.plot(x, np.sin(x))
ax2.plot(x, 10*np.cos(2*x), color='y')

plt.show()

# %%
x1 = np.linspace(0, 2*np.pi, 50)
y1 = np.sin(x1)

x2 = np.linspace(0.0, 2*np.pi, 50)
y2 = np.tan(x2)

# 1*2 구간으로 나누고 1번째에 그리기
plt.subplot(2, 1, 1)
plt.plot(x1, y1)

# 1*2 구간으로 2번째에 그리기
plt.subplot(2, 1, 2)
plt.plot(x2, y2)

plt.show()

# %%
y1 = npr.normal(size=50).cumsum()
y2 = npr.normal(size=100).cumsum()
y3 = npr.normal(size=50).cumsum()
y4 = npr.normal(size=100).cumsum()

# %%
plt.subplot(2, 2, 1)
plt.plot(y1)

plt.subplot(2, 2, 2)
plt.plot(y2)

plt.subplot(223)
plt.plot(y3)

plt.subplot(224)
plt.plot(y4)

plt.show()

# %%
x = np.linspace(0, 2*np.pi, 50)
plt.plot(np.sin(x), label='sin')
plt.plot(np.cos(x), label='cos')
plt.legend()

plt.show()

# %%
x = np.linspace(0, 2*np.pi, 50)

plt.plot(np.sin(x))
plt.plot(np.cos(x))
plt.legend(['sin', 'cos'])
plt.show()

# %% [markdown]
# #### Title and Axis Label, 차트 및 축 이름 설정하기

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, np.sin(x))
plt.title('Title : sin(x)', fontsize=15)
plt.xlabel('X : radians')
plt.ylabel('Y : amplitude')

plt.show()

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, np.sin(x))
plt.title('Line Plot : sin(x)', fontsize = 15)
plt.xlabel('X : radians')
plt.ylabel('Y : amplitude', fontsize='large')

plt.grid()

# %%
y1 = npr.normal(size=50).cumsum()

# (왼쪽) default xlim, ylim
plt.subplot(121)
plt.plot(y1)
plt.title('Y1')

plt.subplot(122)
plt.plot(y1)
plt.xlim(0, 100)
plt.ylim(-10, 10)
plt.title('Y2')

plt.show()

# %%
x = np.linspace(0, 2*np.pi, 20)

plt.plot(x, np.sin(x), color='blue', linestyle='', marker='s')

plt.plot(x, np.cos(x), color='green', linestyle='--', marker='^')

plt.plot(x, np.sin(2*x), color='red', linestyle=':', marker='o')

plt.title('Line Plot')
plt.legend(['item1', 'item2', 'item3'])
plt.show()

# %%
# Plot with Error bars
x = np.linspace(0, 2*np.pi, 10)
y = np.sin(x)
xerr = np.linspace(0, 1, 10) / 5
yerr = np.linspace(1, 0, 10) / 5
print(xerr, yerr)

plt.errorbar(x, y, yerr, xerr)

plt.title('Line with errorbars')
plt.legend(['error'])
plt.show()
# Out:
# [0.         0.02222222 0.04444444 0.06666667 0.08888889 0.11111111
#  0.13333333 0.15555556 0.17777778 0.2       ] [0.2        0.17777778 0.15555556 0.13333333 0.11111111 0.08888889
#  0.06666667 0.04444444 0.02222222 0.        ]

# %%
x = np.linspace(0, 2*np.pi, 10)
y = np.sin(x)

xerr = np.linspace(0, 1, 10) / 5
yerr = np.linspace(1, 0, 10) / 5

plt.errorbar(x, y, yerr, xerr, label='both limits (default)')

plt.errorbar(x, y+1, yerr=yerr, uplims=True, label='upolims=True')

plt.errorbar(x, y+3, yerr=yerr, lolims=True, label='lolims=True')

plt.errorbar(x, y+2, yerr=yerr, uplims=[True, False]*5, lolims=[False, True]*5,
            label='subsets of uplims and lolims')

plt.title('Line with errorbars')
plt.legend()
plt.show()

# %%
x = npr.normal(size = 1000)

plt.hist(x)

plt.title('Histogram')
plt.legend(['items'])
plt.show()

# %% [markdown]
# #### 4. Bar Chart

# %%
# plt.bar()
x = ['item1', 'item2', 'item3', 'item4']
y = [32, 123, 53, 11]

plt.bar(x, y)

plt.title('Bar Chart')
plt.legend(['items'])
plt.show()

# %%
x = ['item1', 'item2', 'item3', 'item4']
y = [32, 123, 53, 11]
plt.barh(x, y)

plt.title('Bar Chart')
plt.legend(['items'])
plt.show()

# %%
x = ['item1', 'item2', 'item3', 'item4']
y = [32, 126, 62, 20]

plt.pie(y, labels=x, autopct='%.2f%%', explode=(0, 0.1, 0, 0))

plt.title('Bar Chart')
plt.show()

# %%
x = npr.normal(size=100)
y = npr.normal(size=100)

plt.scatter(x, y, c='red')

plt.scatter(x, y, c='red')

plt.title('Scatter Chart')
plt.legend(['(x, y)'])
plt.show()

# %%
x = npr.normal(size=100)
y = npr.normal(size=100)
z = npr.normal(size=100)*100

plt.scatter(x, y, z, c='violet')

plt.title('Bubble Chart')
plt.legend(['(x, y, z)'])
plt.show()
# Out:
# c:\Users\sms20\anaconda3\lib\site-packages\matplotlib\collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# ColorMap
x = npr.normal(size = 100).reshape(10, 10) / 100
x
# Out:
# array([[ 6.33600513e-03,  1.40448047e-02,  5.20651464e-03,
#          3.62586319e-03, -9.18932538e-03,  4.18408041e-03,
#          2.78930422e-03,  1.65238833e-02, -3.21024040e-02,
#          1.54353370e-02],
#        [ 1.90320315e-03, -5.06670902e-03, -9.54659468e-03,
#          1.69359817e-02,  8.62591617e-03, -1.71860024e-02,
#          7.80994093e-03,  1.29082912e-02,  4.01161486e-03,
#         -1.54946230e-03],
#        [ 8.24188772e-03, -7.89246368e-03, -1.55617127e-02,
#          4.29135314e-03, -8.32555692e-03,  3.23550179e-03,
#          2.76968647e-03, -9.73728377e-03, -1.61535800e-02,
#          1.15271282e-02],
#        [-3.76628947e-03,  3.50587078e-03, -8.48362401e-03,
#          9.94496624e-03, -1.06916948e-02,  1.44558986e-02,
#         -2.42390922e-03,  1.41961838e-02,  1.71176150e-02,
#         -2.42146777e-02],
#        [-3.54364836e-03,  1.09731154e-02, -3.71675358e-03,
#         -3.07787483e-03,  1.80670883e-02, -2.22147977e-02,
#          2.01716552e-02,  1.97928945e-02,  4.68355376e-03,
#          1.36588511e-02],
#        [-2.09197295e-02, -8.16289827e-03,  7.64765259e-04,
#         -8.36036922e-03, -6.48860772e-03, -3.05353584e-03,
#         -4.04621642e-03, -8.06852854e-03,  6.47807414e-03,
#          8.11437369e-03],
#        [-4.04267129e-03,  5.96596266e-05,  2.63166209e-03,
#         -1.69057574e-02,  7.83027070e-03, -2.22422176e-03,
#         -7.68113947e-03,  1.14039774e-02, -1.56131512e-02,
#          1.66422678e-02],
#        [ 8.83981296e-03,  6.62102356e-03,  6.38842393e-03,
#         -1.28010660e-02,  3.03665288e-03, -7.18942230e-03,
#          7.79215232e-03, -5.33331050e-03,  7.64572681e-03,
#          3.56230866e-03],
#        [ 1.49372514e-02, -1.86344335e-03,  9.43764190e-03,
#          5.35059992e-03,  1.38978312e-03,  5.16654071e-03,
#          6.70350476e-03,  1.00243585e-02,  1.15724868e-02,
#         -2.42665793e-03],
#        [ 4.29224840e-03,  1.71351401e-02,  8.99573758e-03,
#          1.84572765e-03,  8.40659301e-03, -2.41875137e-02,
#          4.48553824e-03, -9.07001602e-03,  3.41928247e-03,
#         -2.90232438e-03]])

# %%
plt.imshow(x)
plt.colorbar()

plt.title('Color Map')
plt.show()

# %%
import matplotlib.image as mpimg
img = mpimg.imread('./cat.jpg')
x = img
print(x)
# Out:
# [[[218 209 176]
#   [217 208 175]
#   [216 207 174]
#   ...
#   [230 220 208]
#   [230 220 208]
#   [230 220 208]]
#
#  [[218 209 176]
#   [217 208 175]
#   [216 207 174]
#   ...
#   [231 221 209]
#   [231 221 209]
#   [231 221 209]]
#
#  [[218 209 176]
#   [216 207 174]
#   [216 207 174]
#   ...
#   [232 222 210]
#   [232 222 210]
#   [232 222 210]]
#
#  ...
#
#  [[182 152 118]
#   [182 152 118]
#   [184 154 120]
#   ...
#   [226 214 198]
#   [226 214 198]
#   [225 213 197]]
#
#  [[181 151 117]
#   [182 152 118]
#   [183 153 119]
#   ...
#   [227 215 199]
#   [226 214 198]
#   [225 213 197]]
#
#  [[181 151 117]
#   [182 152 118]
#   [183 153 119]
#   ...
#   [226 214 198]
#   [226 214 198]
#   [225 213 197]]]

# %%
from matplotlib.colors import NoNorm
plt.imshow(x,cmap='gray',norm=NoNorm()); plt.colorbar()
plt.title('Gray Colormap'); plt.gray()

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-5, 5, 0.25)
y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, cmap='cool')


ax.set_xlabel('X values')
ax.set_ylabel('Y values')
ax.set_zlabel('Z values')
plt.title('3D Surface Plot')
plt.show()
# Out:
# C:\Users\sms20\AppData\Local\Temp\ipykernel_8240\434873006.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
X = npr.normal(size=100)
Y = npr.normal(size=100)
Z = npr.normal(size=100)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X, Y, Z, marker='o')

ax.set_xlabel('X values')
ax.set_ylabel('Y values')
ax.set_zlabel('Z values')
plt.title('3D Scatter chart')
plt.show()
# Out:
# C:\Users\sms20\AppData\Local\Temp\ipykernel_8240\3676891798.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
